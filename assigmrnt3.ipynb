# %%
import pandas as pd

dataTrain = pd.read_csv('Laptop_price.csv')

dataTrain.head()
# Out:
#     Brand       Model            CPU  Processor_Speed  RAM_Size  \
# 0    Asus  ExpertBook  Intel Core i5         3.830296        16
# 1    Acer          Go  Intel Celeron         2.912833         4
# 2  Lenovo  ExpertBook  Intel Core i3         3.241627         4
# 3    Acer      Katana  Intel Core i7         3.806248        16
# 4    Acer         15S  Intel Core i5         3.268097        32
#
#    Storage_Capacity  Screen_Size    Weight Touch         Price
# 0               512    11.185147  2.641094    No  17395.093060
# 1              1000    11.311372  3.260012    No  31607.605920
# 2               256    11.853023  2.029061    No   9291.023542
# 3               512    12.280360  4.573865    No  17436.728330
# 4              1000    14.990877  4.193472    No  32917.990720

# %%
type(dataTrain)  #data type
# Out:
# pandas.core.frame.DataFrame

# %%
dataTrain.shape # check dimension
# Out:
# (1000, 10)

# %%
dataTrain.isnull().sum()
# Out:
# Brand               0
# Model               0
# CPU                 0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Touch               0
# Price               0
# dtype: int64

# %%
dataTrain.dtypes
# Out:
# Brand                object
# Model                object
# CPU                  object
# Processor_Speed     float64
# RAM_Size              int64
# Storage_Capacity      int64
# Screen_Size         float64
# Weight              float64
# Touch                object
# Price               float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
corr= dataTrain.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
#sns.heatmap(df, cmap="YlGnBu", ax=axs[0, 0])

#corr = dataTrain.corr()
##This is a pandas DataFrame method that is used to calculate the correlation between variables in the DataFrame.
#sns.heatmap(df_heatmap,annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import seaborn as sns
#       4 plt.figure(figsize=(10,6))
# ----> 5 corr= dataTrain.corr(numeric_only=True)
#       6 sns.heatmap(corr, annot=True)
#       7 #sns.heatmap(df, cmap="YlGnBu", ax=axs[0, 0])
#       8
#       9 #corr = dataTrain.corr()
#      10 ##This is a pandas DataFrame method that is used to calculate the correlation between variables in the DataFrame.
#      11 #sns.heatmap(df_heatmap,annot=True)
#
# NameError: name 'dataTrain' is not defined

# %%
#generate various summary statistics of a DataFrame
#Note: Only features with numeric data are considered
dataTrain.describe()
# Out:
#        Processor_Speed     RAM_Size  Storage_Capacity  Screen_Size  \
# count      1000.000000  1000.000000       1000.000000  1000.000000
# mean          2.750611    15.500000        584.576000    14.056790
# std           0.731796    10.988665        313.438517     1.705882
# min           1.511580     4.000000        256.000000    11.012111
# 25%           2.089246     8.000000        256.000000    12.635523
# 50%           2.760885    16.000000        512.000000    14.099643
# 75%           3.362610    32.000000       1000.000000    15.528589
# max           3.998534    32.000000       1000.000000    16.985737
#
#             Weight         Price
# count  1000.000000   1000.000000
# mean      3.466919  19604.187963
# std       0.866541   9406.064880
# min       2.000560   8570.012950
# 25%       2.717211  10114.012945
# 50%       3.464630  17287.241880
# 75%       4.212583  31566.214750
# max       4.990728  33503.935040

# %%
import matplotlib.pyplot as plt

dataTrain['Price'].plot(kind = 'hist', bins = 5, edgecolor='black')   # 5 bins are used
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Prices')
plt.show()

# %%
#Search for price = 1 , if so, change the price to 500
dataTrain.loc[dataTrain['Price'] == 1, 'Price'] = 500

# %%
dataTrain.describe(include = 'object')
# Out:
#        Brand    Model            CPU Touch
# count   1000     1000           1000  1000
# unique     5       93             21     2
# top     Dell  IdeaPad  Intel Core i7    No
# freq     210       63            290   897

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.regplot(x="Processor_Speed", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Processor_Speed', ylabel='Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Processor_Speed'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.05073733182221746  with a P-value of P = 0.10882841249771104

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="RAM_Size", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='RAM_Size', ylabel='Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['RAM_Size'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.06123673783246338  with a P-value of P = 0.05288354132588282

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.regplot(x="Storage_Capacity", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Storage_Capacity', ylabel='Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Storage_Capacity'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9979078468030569  with a P-value of P = 0.0

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.regplot(x="Screen_Size", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Screen_Size', ylabel='Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Screen_Size'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.026739766033138535  with a P-value of P = 0.3982900367441111

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.regplot(x="Weight", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Weight'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.038416629822112996  with a P-value of P = 0.22483589383536104

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Brand", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="Model", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Model', ylabel='Price'>

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="CPU", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='CPU', ylabel='Price'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Touch", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Touch', ylabel='Price'>

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
dataTrain.Brand = labelencoder.fit_transform(dataTrain.Brand)
dataTrain.Model = labelencoder.fit_transform(dataTrain.Model)
dataTrain.CPU = labelencoder.fit_transform(dataTrain.CPU)
dataTrain.Processor_Speed = labelencoder.fit_transform(dataTrain.Processor_Speed)
dataTrain.RAM_Size = labelencoder.fit_transform(dataTrain.RAM_Size)
dataTrain.Storage_Capacity = labelencoder.fit_transform(dataTrain.Storage_Capacity)
dataTrain.Screen_Size = labelencoder.fit_transform(dataTrain.Screen_Size)
dataTrain.Weight = labelencoder.fit_transform(dataTrain.Weight)
dataTrain.Touch = labelencoder.fit_transform(dataTrain.Touch)

# %%
dataTrain.head(10)
# Out:
#    Brand  Model  CPU  Processor_Speed  RAM_Size  Storage_Capacity  \
# 0      1     31   13              927         2                 1
# 1      0     38   11              555         0                 2
# 2      4     31   12              704         0                 0
# 3      0     42   14              915         2                 1
# 4      0      3   13              712         3                 2
# 5      3     22   14              164         2                 0
# 6      4     79    5              563         3                 0
# 7      4     87   14              595         0                 0
# 8      4     10   13              418         0                 1
# 9      0     86   14              740         3                 1
#
#    Screen_Size  Weight  Touch         Price
# 0           33     228      0  17395.093060
# 1           53     432      0  31607.605920
# 2          132      10      0   9291.023542
# 3          194     871      0  17436.728330
# ...

# %%
# Calculate the z-score from with scipy
import scipy.stats as stats
dataTrain = stats.zscore(dataTrain)

# %%
dataTrain
# Out:
#         Brand     Model       CPU  Processor_Speed  RAM_Size  \
# 0   -0.681111 -0.707939  0.311089         1.480904  0.404466
# 1   -1.393570 -0.446224 -0.229936         0.192258 -1.361759
# 2    1.456266 -0.707939  0.040577         0.708409 -1.361759
# 3   -1.393570 -0.296673  0.581602         1.439335  0.404466
# 4   -1.393570 -1.754800  0.311089         0.736122  1.287578
# ..        ...       ...       ...              ...       ...
# 995  0.743807 -0.259285  0.311089         0.843509 -1.361759
# 996  0.031348  1.086679  0.581602         0.015588 -0.478647
# 997  0.031348  1.385782  0.311089         0.614878 -1.361759
# 998 -0.681111  0.114594  0.852114        -1.564043 -0.478647
# 999  1.456266 -0.446224 -0.229936        -1.415086 -1.361759
#
#      Storage_Capacity  Screen_Size    Weight     Touch     Price
# 0            0.025234    -1.616004 -0.940504 -0.338862 -0.234976
# 1            1.226867    -1.546722 -0.233827 -0.338862  1.276775
# ...

# %%
x_train=dataTrain.iloc[:,0:9]
y_train=dataTrain.iloc[:,9]



#x_test=dataTrain.iloc[:,0:9]
#y_test=dataTrain.iloc[:,9]

# %%
#In case you have no separate testing data, use the following code
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size = 0.3, random_state = 0)
#30% of the trainng data will be used for testing

# %%
x_train.head()
# Out:
#         Brand     Model       CPU  Processor_Speed  RAM_Size  \
# 105 -1.393570  1.385782  0.581602        -1.640253 -1.361759
# 68  -0.681111 -1.081818  0.581602        -0.365463  1.287578
# 479 -1.393570 -0.446224  1.934164        -1.335412 -1.361759
# 399  0.743807  0.226757  0.581602         1.283450 -1.361759
# 434 -0.681111  0.264145  0.581602         1.359661 -1.361759
#
#      Storage_Capacity  Screen_Size    Weight     Touch
# 105          1.226867    -1.425479  0.382783 -0.338862
# 68          -1.176398     1.674894 -1.560579 -0.338862
# 479         -1.176398     1.279986  1.252273 -0.338862
# 399          0.025234    -0.244219 -0.029445 -0.338862
# 434          1.226867    -0.005196 -0.143760 -0.338862

# %%
y_train.head()
# Out:
# 105    1.233195
# 68    -0.961352
# 479   -1.103850
# 399   -0.258239
# 434    1.274783
# Name: Price, dtype: float64

# %%
#Multiple Linear Regression
#Calling multiple linear regression model and fitting the training set

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model_mlr = model.fit(x_train,y_train)

# %%
#Making price prediction using the testing set (Fit to MLR)

y_pred1 = model_mlr.predict(x_test)

# %%
#randomly checking the y-test values
y_test.iloc[0]
# Out:
# 1.272977991777342

# %%
#randomly checking the y-pred values
y_pred1[0]
# Out:
# 1.1493453320200546

# %%
#MLR Evaluation
#Calculating the Mean Square Error for MLR model
from sklearn.metrics import mean_squared_error
mse1 = mean_squared_error(y_test, y_pred1)
print('The mean square error for Multiple Linear Regression: ', mse1)
# Out:
# The mean square error for Multiple Linear Regression:  0.03004555863186501

# %%
#Calculating the Mean Absolute Error for MLR model
from sklearn.metrics import mean_absolute_error
mae1= mean_absolute_error(y_test, y_pred1)
print('The mean absolute error for Multiple Linear Regression: ', mae1)
# Out:
# The mean absolute error for Multiple Linear Regression:  0.15901886707783258

# %%
#Random Forest Regressor (checking other Models)
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
model_rf = rf.fit(x_train,y_train)

# %%
#Prediction of laptop price using the testing data
y_pred2 = model_rf.predict(x_test)

# %%
#Calculating the Mean Square Error for Random Forest Model (Lowest MSE value)
mse2 = mean_squared_error(y_test, y_pred2)
print('The mean square error of price and predicted value is: ', mse2)
# Out:
# The mean square error of price and predicted value is:  0.0005750290317184681

# %%
#Calculating the Mean Absolute Error for Random Forest Model (Lowest Mean Absolute Error)
mae2= mean_absolute_error(y_test, y_pred2)
print('The mean absolute error of price and predicted value is: ', mae2)
# Out:
# The mean absolute error of price and predicted value is:  0.018954928639471045

# %%
#LASSO Model
#Calling the model and fitting the training data
from sklearn.linear_model import LinearRegression,Lasso
LassoModel = Lasso()
model_lm = LassoModel.fit(x_train,y_train)

# %%
#Price prediction uisng testing data
y_pred3 = model_lm.predict(x_test)

# %%
#Mean Absolute Error for LASSO Model
mae3= mean_absolute_error(y_test, y_pred3)
print('The mean absolute error of price and predicted value is: ', mae3)
# Out:
# The mean absolute error of price and predicted value is:  0.8940717691293797

# %%
#Mean Squared Error for the LASSO Model
mse3 = mean_squared_error(y_test, y_pred3)
print('The mean square error of price and predicted value is: ', mse3)
# Out:
# The mean square error of price and predicted value is:  0.9931516209513478

# %%
scores = [('MLR', mae1),
          ('Random Forest', mae2),
          ('LASSO', mae3)
         ]

# %%
mae = pd.DataFrame(data = scores, columns=['Model', 'MAE Score'])
mae
# Out:
#            Model  MAE Score
# 0            MLR   0.159019
# 1  Random Forest   0.018955
# 2          LASSO   0.894072

# %%
import matplotlib.pyplot as plt
import seaborn as sns
mae.sort_values(by=(['MAE Score']), ascending=False, inplace=True)

f, axe = plt.subplots(1,1, figsize=(10,3))
sns.barplot(x = mae['Model'], y=mae['MAE Score'], ax = axe)
axe.set_xlabel('Model', size=15)
axe.set_ylabel('Mean Absolute Error', size=15)

plt.show()

# %%
#Based on the MAE, it is concluded that the Random Forest is the best regression model for predicting the car price based on the 12 predictor variables
